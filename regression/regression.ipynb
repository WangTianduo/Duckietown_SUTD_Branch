# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(0)
points = 500
X = np.linspace(-3, 3, points)
y = np.sin(X) + np.random.uniform(-0.5, 0.5, points)

# %%
model = Sequential()
model.add(Dense(50, activation='tanh', input_dim=1))
model.add(Dense(50, activation='sigmoid'))
model.add(Dense(1))

# %%
adam = Adam(lr=0.01)
model.compile(loss='mse', optimizer=adam)
model.fit(X, y, epochs=50)
# Out:
# Epoch 1/50
# 500/500 [==============================] - 0s 515us/step - loss: 0.2957
# Epoch 2/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.2502
# Epoch 3/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.1703
# Epoch 4/50
# 500/500 [==============================] - 0s 41us/step - loss: 0.1328
# Epoch 5/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.1182
# Epoch 6/50
# 500/500 [==============================] - 0s 38us/step - loss: 0.1187
# Epoch 7/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.1154
# Epoch 8/50
# 500/500 [==============================] - 0s 38us/step - loss: 0.1116
# Epoch 9/50
# 500/500 [==============================] - 0s 37us/step - loss: 0.1075
# Epoch 10/50
# 500/500 [==============================] - 0s 36us/step - loss: 0.1022
# Epoch 11/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.1117
# Epoch 12/50
# 500/500 [==============================] - 0s 42us/step - loss: 0.1087
# Epoch 13/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.1104
# Epoch 14/50
# 500/500 [==============================] - 0s 42us/step - loss: 0.1102
# Epoch 15/50
# 500/500 [==============================] - 0s 41us/step - loss: 0.1023
# Epoch 16/50
# 500/500 [==============================] - 0s 41us/step - loss: 0.1122
# Epoch 17/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.1070
# Epoch 18/50
# 500/500 [==============================] - 0s 46us/step - loss: 0.1049
# Epoch 19/50
# 500/500 [==============================] - 0s 41us/step - loss: 0.0993
# Epoch 20/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.1000
# Epoch 21/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.0964
# Epoch 22/50
# 500/500 [==============================] - 0s 47us/step - loss: 0.1100
# Epoch 23/50
# 500/500 [==============================] - 0s 42us/step - loss: 0.0976
# Epoch 24/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.1005
# Epoch 25/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.1059
# Epoch 26/50
# 500/500 [==============================] - 0s 46us/step - loss: 0.1022
# Epoch 27/50
# 500/500 [==============================] - 0s 42us/step - loss: 0.1125
# Epoch 28/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.1025
# Epoch 29/50
# 500/500 [==============================] - 0s 36us/step - loss: 0.1040
# Epoch 30/50
# 500/500 [==============================] - 0s 41us/step - loss: 0.0942
# Epoch 31/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.0957
# Epoch 32/50
# 500/500 [==============================] - 0s 35us/step - loss: 0.0972
# Epoch 33/50
# 500/500 [==============================] - 0s 44us/step - loss: 0.0984
# Epoch 34/50
# 500/500 [==============================] - 0s 41us/step - loss: 0.1008
# Epoch 35/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.0939
# Epoch 36/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.0983
# Epoch 37/50
# 500/500 [==============================] - 0s 51us/step - loss: 0.1066
# Epoch 38/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.0974
# Epoch 39/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.0954
# Epoch 40/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.0962
# Epoch 41/50
# 500/500 [==============================] - 0s 42us/step - loss: 0.1058
# Epoch 42/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.1101
# Epoch 43/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.0977
# Epoch 44/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.0945
# Epoch 45/50
# 500/500 [==============================] - 0s 46us/step - loss: 0.0965
# Epoch 46/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.0983
# Epoch 47/50
# 500/500 [==============================] - 0s 41us/step - loss: 0.0933
# Epoch 48/50
# 500/500 [==============================] - 0s 42us/step - loss: 0.0980
# Epoch 49/50
# 500/500 [==============================] - 0s 39us/step - loss: 0.0988
# Epoch 50/50
# 500/500 [==============================] - 0s 38us/step - loss: 0.0990

# %%
predictions = model.predict(X)
plt.scatter(X, y)
plt.plot(X, predictions, 'ro')
plt.show()
